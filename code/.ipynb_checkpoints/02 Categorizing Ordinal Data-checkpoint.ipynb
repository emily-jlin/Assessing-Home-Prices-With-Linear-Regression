# %% [markdown]
# ## Categorizing Ordinal Data

# %%
train_data.columns
# Out:
# Index(['index', 'Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage',
#        'Lot Area', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
train_data.dtypes
# Out:
# index           int64
# Id              int64
# PID             int64
# MS SubClass     int64
# MS Zoning      object
#                 ...
# Mo Sold         int64
# Yr Sold         int64
# Sale Type      object
# SalePrice       int64
# split          object
# Length: 83, dtype: object

# %% [markdown]
# #### Lot Shape
#
# |Lot Shape (Ordinal): |General shape of property|Scale in dataframe|
# |---------------------|------------------------|-------------------|
# |Reg|Regular|3|
# |IR1	|Slightly irregular|2|
#        |IR2	|Moderately Irregular|1|
#        |IR3	|Irregular|0|

# %%
combined.groupby(['Lot Shape']).count()
# Out:
#            index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Lot Shape
# IR1          966   966   966          966        966           966       966
# IR2           75    75    75           75         75            75        75
# IR3           16    16    16           16         16            16        16
# Reg         1847  1847  1847         1847       1847          1847      1847
#
#            Street  Alley  Land Contour  ...  Pool Area  Pool QC  Fence  \
# Lot Shape                               ...
# IR1           966    966           966  ...        966      966    966
# IR2            75     75            75  ...         75       75     75
# IR3            16     16            16  ...         16       16     16
# Reg          1847   1847          1847  ...       1847     1847   1847
#
#            Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice  \
# Lot Shape
# IR1                 966       966      966      966        966        680
# ...

# %%
combined['Lot Shape'] = combined['Lot Shape'].map({'Reg':3, 'IR1':2, 'IR2':1, 'IR3':0})

# %%
combined['Lot Shape'].head()
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    2
# Name: Lot Shape, dtype: int64

# %%
combined['Lot Shape'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Utilities
#
# |Utilities (Ordinal):| Type of utilities available|Scale in dataframe|
# |--------------------|----------------------------|------------------|
# |AllPub	|All public Utilities (E,G,W,& S)	|3|
# |NoSewr|	Electricity, Gas, and Water (Septic Tank)|2|
# |NoSeWa|	Electricity and Gas Only|1|
# |ELO	|Electricity only|0|

# %%
combined.groupby(['Utilities']).count()
# Out:
#            index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Utilities
# AllPub      2901  2901  2901         2901       2901          2901      2901
# NoSeWa         1     1     1            1          1             1         1
# NoSewr         2     2     2            2          2             2         2
#
#            Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Utilities                            ...
# AllPub       2901   2901       2901  ...       2901     2901   2901
# NoSeWa          1      1          1  ...          1        1      1
# NoSewr          2      2          2  ...          2        2      2
#
#            Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice  \
# Utilities
# AllPub             2901      2901     2901     2901       2901       2024
# NoSeWa                1         1        1        1          1          1
# NoSewr                2         2        2        2          2          1
#
# ...

# %%
combined['Utilities'] = combined['Utilities'].map({'AllPub':3, 'NoSewr':2, 'NoSeWa':1, 'ELO':0})

# %%
combined['Utilities'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Utilities, dtype: int64

# %%
combined['Utilities'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Land Slope
# |Land Slope (Ordinal):| Slope of property|Scale in dataframe|
# |---------------------|------------------|------------------|
# |Gtl|	Gentle slope|2|
# |Mod|Moderate Slope	|1|
# |Sev|Severe Slope|0|

# %%
combined.groupby(['Land Slope']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Land Slope
# Gtl          2763  2763  2763         2763       2763          2763      2763
# Mod           125   125   125          125        125           125       125
# Sev            16    16    16           16         16            16        16
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Land Slope                            ...
# Gtl           2763   2763       2763  ...       2763     2763   2763
# Mod            125    125        125  ...        125      125    125
# Sev             16     16         16  ...         16       16     16
#
#             Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice  \
# Land Slope
# Gtl                 2763      2763     2763     2763       2763       1928
# Mod                  125       125      125      125        125         88
# Sev                   16        16       16       16         16         10
#
# ...

# %%
combined['Land Slope'] = combined['Land Slope'].map({'Gtl':2, 'Mod':1, 'Sev':0})

# %%
combined['Land Slope'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Land Slope, dtype: int64

# %%
combined['Land Slope'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Overall Qual
# Overall Qual (Ordinal): Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# No need to clean

# %% [markdown]
# #### Overall Condition
# Overall Cond (Ordinal): Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# No need to clean

# %% [markdown]
# #### Exterior Quality
# |Exter Qual (Ordinal): |Evaluates the quality of the material on the exterior |Scale in dataframe|
# |----------------------|------------------------------------------------------|------------------|
# |Ex	|Excellent|4|
# |Gd	|Good|3|
# |TA	|Average/Typical|2|
# |Fa	|Fair|1|
# |Po	|Poor|0|

# %%
combined.groupby(['Exter Qual']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Exter Qual
# Ex            105   105   105          105        105           105       105
# Fa             35    35    35           35         35            35        35
# Gd            969   969   969          969        969           969       969
# TA           1795  1795  1795         1795       1795          1795      1795
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Exter Qual                            ...
# Ex             105    105        105  ...        105      105    105
# Fa              35     35         35  ...         35       35     35
# Gd             969    969        969  ...        969      969    969
# TA            1795   1795       1795  ...       1795     1795   1795
#
#             Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  SalePrice  \
# Exter Qual
# Ex                   105       105      105      105        105         80
# ...

# %%
combined['Exter Qual'] = combined['Exter Qual'].map({'Ex':4, 'Gd':3, 'TA':2, 'Fa':1, 'Po':0})

# %%
combined['Exter Qual'].head()
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    2
# Name: Exter Qual, dtype: int64

# %%
combined['Exter Qual'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Exterior Condition
# |Exter Cond (Ordinal): |Evaluates the present condition of the material on the exterior|Scale in dataframe|
# |----------------------|---------------------------------------------------------------|------------------|
# |Ex	|Excellent|4|
# |Gd	|Good|3|
# |TA	|Average/Typical|2|
# |Fa	|Fair|1|
# |Po	|Poor|0|

# %%
combined.groupby(['Exter Cond']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Exter Cond
# Ex             12    12    12           12         12            12        12
# Fa             67    67    67           67         67            67        67
# Gd            299   299   299          299        299           299       299
# Po              3     3     3            3          3             3         3
# TA           2523  2523  2523         2523       2523          2523      2523
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Exter Cond                            ...
# Ex              12     12         12  ...         12       12     12
# Fa              67     67         67  ...         67       67     67
# Gd             299    299        299  ...        299      299    299
# Po               3      3          3  ...          3        3      3
# TA            2523   2523       2523  ...       2523     2523   2523
#
# ...

# %%
combined['Exter Cond'] = combined['Exter Cond'].map({'Ex':4, 'Gd':3, 'TA':2, 'Fa':1, 'Po':0})

# %%
combined['Exter Cond'].isnull().sum()
# Out:
# 0

# %%
combined['Exter Cond'].head()
# Out:
# 0    2
# 1    2
# 2    3
# 3    2
# 4    2
# Name: Exter Cond, dtype: int64

# %% [markdown]
# #### Bsmt Qual
# |Bsmt Qual (Ordinal):| Evaluates the height of the basement|Scale in dataframe|
# |--------------------|-------------------------------------|------------------|
# |Ex	|Excellent (100+ inches)	|6|
#        |Gd	|Good (90-99 inches)|5|
#       | TA	|Typical (80-89 inches)|4|
#       | Fa	|Fair (70-79 inches)|3|
#       | Po	|Poor (<70 inches|2|
#        |NA	|No Basement|1|
#        |0|Missing values|0|

# %%
combined.groupby(['Bsmt Qual']).count()
# Out:
#            index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Bsmt Qual
# 0             78    78    78           78         78            78        78
# Ex           250   250   250          250        250           250       250
# Fa            88    88    88           88         88            88        88
# Gd          1204  1204  1204         1204       1204          1204      1204
# Po             2     2     2            2          2             2         2
# TA          1282  1282  1282         1282       1282          1282      1282
#
#            Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Bsmt Qual                            ...
# 0              78     78         78  ...         78       78     78
# Ex            250    250        250  ...        250      250    250
# Fa             88     88         88  ...         88       88     88
# Gd           1204   1204       1204  ...       1204     1204   1204
# ...

# %%
combined['Bsmt Qual'] = combined['Bsmt Qual'].map({'Ex':6, 'Gd':5, 'TA':4, 'Fa':3,'Po':2, 'NA':1, 0:0})

# %%
combined['Bsmt Qual'].isnull().sum()
# Out:
# 0

# %%
combined['Bsmt Qual'].head()
# Out:
# 0    4
# 1    5
# 2    4
# 3    5
# 4    3
# Name: Bsmt Qual, dtype: int64

# %% [markdown]
# #### Bsmt Condition
# |Bsmt Cond (Ordinal):| Evaluates the general condition of the basement|Scale in dataframe|
# |--------------------|------------------------------------------------|------------------|
# |Ex	|Excellent|6|
#        |Gd	|Good|5|
#        |TA	|Typical - slight dampness allowed|4|
#        |Fa	|Fair - dampness or some cracking or settling|3|
#        |Po	|Poor - Severe cracking, settling, or wetness|2|
#        |NA	|No Basement|1|
#        |0|Missing Values|0|

# %%
combined.groupby(['Bsmt Cond']).count()
# Out:
#            index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Bsmt Cond
# 0             78    78    78           78         78            78        78
# Ex             3     3     3            3          3             3         3
# Fa           104   104   104          104        104           104       104
# Gd           120   120   120          120        120           120       120
# Po             5     5     5            5          5             5         5
# TA          2594  2594  2594         2594       2594          2594      2594
#
#            Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Bsmt Cond                            ...
# 0              78     78         78  ...         78       78     78
# Ex              3      3          3  ...          3        3      3
# Fa            104    104        104  ...        104      104    104
# Gd            120    120        120  ...        120      120    120
# ...

# %%
combined['Bsmt Cond'] = combined['Bsmt Cond'].map({'Ex':6, 'Gd':5, 'TA':4, 'Fa':3,'Po':2, 'NA':1, 0:0})

# %%
combined['Bsmt Cond'].isnull().sum()
# Out:
# 0

# %%
combined['Bsmt Cond'].head()
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    5
# Name: Bsmt Cond, dtype: int64

# %% [markdown]
# #### Bsmt Exposure
# |Bsmt Exposure	(Ordinal): |Refers to walkout or garden level walls|Scale in Dataframe|
# |--------------------------|---------------------------------------|------------------|
# |Gd	|Good Exposure|4|
#        |Av	|Average Exposure (split levels or foyers typically score average or above)	|3|
#        |Mn	|Mimimum Exposure|3|
#        |No	|No Exposure|2|
#        |NA	|No Basement|1|
#        |0|Missing Values|0|

# %%
combined.groupby(['Bsmt Exposure']).count()
# Out:
#                index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Bsmt Exposure
# 0                 81    81    81           81         81            81
# Av               414   414   414          414        414           414
# Gd               282   282   282          282        282           282
# Mn               239   239   239          239        239           239
# No              1888  1888  1888         1888       1888          1888
#
#                Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Bsmt Exposure                                      ...
# 0                    81      81     81         81  ...         81       81
# Av                  414     414    414        414  ...        414      414
# Gd                  282     282    282        282  ...        282      282
# Mn                  239     239    239        239  ...        239      239
# No                 1888    1888   1888       1888  ...       1888     1888
#
# ...

# %%
combined['Bsmt Exposure'] = combined['Bsmt Exposure'].map({'Gd':4, 'Av':3,'Mn':3,'No':2, 'NA':1, 0:0})

# %%
combined['Bsmt Exposure'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Bsmt Exposure, dtype: int64

# %%
combined['Bsmt Exposure'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Bsmt finished area
# |BsmtFin Type 1	(Ordinal):| Rating of basement finished area|Scale in dataframe|
# |-------------------------|---------------------------------|------------------|
# |GLQ|	Good Living Quarters|7|
#        |ALQ|	Average Living Quarters|6|
#        |BLQ	|Below Average Living Quarters|5	|
#        |Rec	|Average Rec Room|4|
#        |LwQ	|Low Quality|3|
#        |Unf	|Unfinshed|2|
#        |NA	|No Basement|1|
#        |0|Missing Values|0|

# %%
combined.groupby(['BsmtFin Type 1']).count()
# Out:
#                 index   Id  PID  MS SubClass  MS Zoning  Lot Frontage  \
# BsmtFin Type 1
# 0                  78   78   78           78         78            78
# ALQ               428  428  428          428        428           428
# BLQ               269  269  269          269        269           269
# GLQ               847  847  847          847        847           847
# LwQ               154  154  154          154        154           154
# Rec               287  287  287          287        287           287
# Unf               841  841  841          841        841           841
#
#                 Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# BsmtFin Type 1                                      ...
# 0                     78      78     78         78  ...         78       78
# ALQ                  428     428    428        428  ...        428      428
# BLQ                  269     269    269        269  ...        269      269
# ...

# %%
combined['BsmtFin Type 1'] = combined['BsmtFin Type 1'].map({'GLQ':7, 'ALQ':6, 'BLQ':5, 'Rec':4, 'LwQ':3, 'Unf':2, 'NA':1, 0:0})

# %%
combined['BsmtFin Type 1'].isnull().sum()
# Out:
# 0

# %%
combined['BsmtFin Type 1'].head()
# Out:
# 0    7
# 1    7
# 2    7
# 3    2
# 4    2
# Name: BsmtFin Type 1, dtype: int64

# %% [markdown]
# #### Bsmt Finished Type 2
# |BsmtFin Type 2	(Ordinal):| Rating of basement finished area|Scale in dataframe|
# |-------------------------|---------------------------------|------------------|
# |GLQ|	Good Living Quarters|7|
#        |ALQ|	Average Living Quarters|6|
#        |BLQ	|Below Average Living Quarters|5	|
#        |Rec	|Average Rec Room|4|
#        |LwQ	|Low Quality|3|
#        |Unf	|Unfinshed|2|
#        |NA	|No Basement|1|
#        |0|Missing Values|0|

# %%
combined.groupby(['BsmtFin Type 2']).count()
# Out:
#                 index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# BsmtFin Type 2
# 0                  79    79    79           79         79            79
# ALQ                52    52    52           52         52            52
# BLQ                68    68    68           68         68            68
# GLQ                34    34    34           34         34            34
# LwQ                89    89    89           89         89            89
# Rec               106   106   106          106        106           106
# Unf              2476  2476  2476         2476       2476          2476
#
#                 Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# BsmtFin Type 2                                      ...
# 0                     79      79     79         79  ...         79       79
# ALQ                   52      52     52         52  ...         52       52
# BLQ                   68      68     68         68  ...         68       68
# ...

# %%
combined['BsmtFin Type 2'] = combined['BsmtFin Type 2'].map({'GLQ':7, 'ALQ':6, 'BLQ':5, 'Rec':4, 'LwQ':3, 'Unf':2, 'NA':1, 0:0})

# %%
combined['BsmtFin Type 2'].isnull().sum()
# Out:
# 0

# %%
combined['BsmtFin Type 2'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: BsmtFin Type 2, dtype: int64

# %% [markdown]
# ### Heating QC
# |HeatingQC (Ordinal): |Heating quality and condition|Scale in dataframe|
# |---------------------|-----------------------------|------------------|
#        |Ex	|Excellent|4|
#        |Gd	|Good|3|
#        |TA	|Average/Typical|2|
#        |Fa	|Fair|1|
#        |Po	|Poor|0|

# %%
combined.groupby(['Heating QC']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Heating QC
# Ex           1472  1472  1472         1472       1472          1472      1472
# Fa             92    92    92           92         92            92        92
# Gd            476   476   476          476        476           476       476
# Po              3     3     3            3          3             3         3
# TA            861   861   861          861        861           861       861
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Heating QC                            ...
# Ex            1472   1472       1472  ...       1472     1472   1472
# Fa              92     92         92  ...         92       92     92
# Gd             476    476        476  ...        476      476    476
# Po               3      3          3  ...          3        3      3
# TA             861    861        861  ...        861      861    861
#
# ...

# %%
combined['Heating QC'] = combined['Heating QC'].map({
    'Ex':4,
    'Gd':3,
    'TA':2,
    'Fa':1,
    'Po':0
})

# %%
combined['Heating QC'].isnull().sum()
# Out:
# 0

# %%
combined['Heating QC'].head()
# Out:
# 0    4
# 1    4
# 2    2
# 3    3
# 4    2
# Name: Heating QC, dtype: int64

# %% [markdown]
#
# |Electrical (Ordinal): |Electrical system|Scale in dataframe|
# |-|-|-|
# |SBrkr	|Standard Circuit Breakers & Romex|3|
#        |FuseA	|Fuse Box over 60 AMP and all Romex wiring (Average)	|2|
#        |FuseF	|60 AMP Fuse Box and mostly Romex wiring (Fair)|1|
#        |FuseP	|60 AMP Fuse Box and mostly knob & tube wiring (poor)|0|
#        |Mix	|Mixed|1.5|

# %%
combined.groupby(['Electrical']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Electrical
# FuseA         187   187   187          187        187           187       187
# FuseF          50    50    50           50         50            50        50
# FuseP           8     8     8            8          8             8         8
# Mix             1     1     1            1          1             1         1
# NA              1     1     1            1          1             1         1
# SBrkr        2657  2657  2657         2657       2657          2657      2657
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Electrical                            ...
# FuseA          187    187        187  ...        187      187    187
# FuseF           50     50         50  ...         50       50     50
# FuseP            8      8          8  ...          8        8      8
# Mix              1      1          1  ...          1        1      1
# ...

# %%
combined['Electrical'] = combined['Electrical'].map({
    'SBrkr':3,
    'FuseA':2,
    'FuseF':1,
    'FuseP':0,
    'Mix':1.5,
    'NA':0
    
})

# %%
combined['Electrical'].head()
# Out:
# 0    3.0
# 1    3.0
# 2    3.0
# 3    3.0
# 4    3.0
# Name: Electrical, dtype: float64

# %%
combined['Electrical'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Kitchen Quality
# |KitchenQual (Ordinal): |Kitchen quality|Scale in dataframe|
# |-|-|-|
#        |Ex	|Excellent|4|
#        |Gd	|Good|3|
#        |TA	|Typical/Average|2|
#        |Fa	|Fair|1|
#        |Po	|Poor|0|

# %%
combined.groupby(['Kitchen Qual']).count()
# Out:
#               index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Kitchen Qual
# Ex              199   199   199          199        199           199
# Fa               70    70    70           70         70            70
# Gd             1143  1143  1143         1143       1143          1143
# Po                1     1     1            1          1             1
# TA             1491  1491  1491         1491       1491          1491
#
#               Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Kitchen Qual                                      ...
# Ex                 199     199    199        199  ...        199      199
# Fa                  70      70     70         70  ...         70       70
# Gd                1143    1143   1143       1143  ...       1143     1143
# Po                   1       1      1          1  ...          1        1
# TA                1491    1491   1491       1491  ...       1491     1491
#
# ...

# %%
combined['Kitchen Qual'] = combined['Kitchen Qual'].map({
    'Ex':4,
    'Gd':3,
    'TA':2,
    'Fa':1,
    'Po':0
    
})

# %%
combined['Kitchen Qual'].isnull().sum()
# Out:
# 0

# %%
combined['Kitchen Qual'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    2
# 4    2
# Name: Kitchen Qual, dtype: int64

# %% [markdown]
# #### Functional
# |Functional (Ordinal): |Home functionality (Assume typical unless deductions are warranted)|Scale in dataframe|
# |-|-|-|
# |Typ	|Typical Functionality|7|
#        |Min1	|Minor Deductions 1|6|
#        |Min2	|Minor Deductions 2|5|
#        |Mod	|Moderate Deductions|4|
#        |Maj1	|Major Deductions 1|3|
#        |Maj2	|Major Deductions 2|2|
#        |Sev	|Severely Damaged|1|
#        |Sal	|Salvage only|0|

# %%
combined.groupby(['Functional']).count()
# Out:
#             index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Functional
# Maj1           18    18    18           18         18            18        18
# Maj2            9     9     9            9          9             9         9
# Min1           65    65    65           65         65            65        65
# Min2           70    70    70           70         70            70        70
# Mod            35    35    35           35         35            35        35
# Sal             2     2     2            2          2             2         2
# Sev             2     2     2            2          2             2         2
# Typ          2703  2703  2703         2703       2703          2703      2703
#
#             Street  Alley  Lot Shape  ...  Pool Area  Pool QC  Fence  \
# Functional                            ...
# Maj1            18     18         18  ...         18       18     18
# Maj2             9      9          9  ...          9        9      9
# ...

# %%
combined['Functional'] = combined['Functional'].map({
    'Typ':7,
    'Min1':6,
    'Min2':5,
    'Mod':4,
    'Maj1':3,
    'Maj2':2,
    'Sev':1,
    'Sal':0
    
})

# %%
combined['Functional'].isnull().sum()
# Out:
# 0

# %%
combined['Functional'].head()
# Out:
# 0    7
# 1    7
# 2    7
# 3    7
# 4    7
# Name: Functional, dtype: int64

# %% [markdown]
# #### Fireplace quality
# |FireplaceQu (Ordinal):| Fireplace quality|Scale in dataframe|
# |-|-|-|
#        |Ex	|Excellent - Exceptional Masonry Fireplace|6|
#       | Gd	|Good - Masonry Fireplace in main level|5|
#        |TA	|Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement|4|
#        |Fa	|Fair - Prefabricated Fireplace in basement|3|
#        |Po	|Poor - Ben Franklin Stove|2|
#        |NA	|No Fireplace|0|
# 		|0|Missing values|0

# %%
combined.groupby(['Fireplace Qu']).count()
# Out:
#               index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Fireplace Qu
# 0              1412  1412  1412         1412       1412          1412
# Ex               43    43    43           43         43            43
# Fa               75    75    75           75         75            75
# Gd              733   733   733          733        733           733
# Po               46    46    46           46         46            46
# TA              595   595   595          595        595           595
#
#               Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Fireplace Qu                                      ...
# 0                 1412    1412   1412       1412  ...       1412     1412
# Ex                  43      43     43         43  ...         43       43
# Fa                  75      75     75         75  ...         75       75
# Gd                 733     733    733        733  ...        733      733
# ...

# %%
combined['Fireplace Qu'] = combined['Fireplace Qu'].map({
   'Ex':6,
    'Gd':5,
    'TA':4,
    'Fa':3,
    'Po':2,
    'NA':0,
    0:0
})

# %%
combined['Fireplace Qu'].isnull().sum()
# Out:
# 0

# %%
combined['Fireplace Qu'].head()
# Out:
# 0    0
# 1    4
# 2    0
# 3    0
# 4    0
# Name: Fireplace Qu, dtype: int64

# %% [markdown]
# #### Garage Finish
# |Garage Finish (Ordinal)	: |Interior finish of the garage|Scale in dataframe|
# |-|-|-|
# |Fin	|Finished|4|
#       | RFn	|Rough Finished	|3|
#        |Unf	|Unfinished|2|
#        |NA	|No Garage|1|
#        |0|Missing values|0|

# %%
combined.groupby(['Garage Finish']).count()
# Out:
#                index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Garage Finish
# 0                157   157   157          157        157           157
# Fin              715   715   715          715        715           715
# RFn              805   805   805          805        805           805
# Unf             1227  1227  1227         1227       1227          1227
#
#                Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Garage Finish                                      ...
# 0                   157     157    157        157  ...        157      157
# Fin                 715     715    715        715  ...        715      715
# RFn                 805     805    805        805  ...        805      805
# Unf                1227    1227   1227       1227  ...       1227     1227
#
#                Fence  Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  \
# Garage Finish
# ...

# %%
combined['Garage Finish'] = combined['Garage Finish'].map({
   'Fin':4,
    'RFn':3,
    'Unf':3,
    'NA':1,
    0:0
})

# %%
combined['Garage Finish'].isnull().sum()
# Out:
# 0

# %%
combined['Garage Finish'].head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    4
# 4    3
# Name: Garage Finish, dtype: int64

# %% [markdown]
# #### Garage Quality
# |Garage Qual (Ordinal): |Garage quality|Scale in dataframe|
# |-|-|-|
#        |Ex	|Excellent|5|
#        |Gd	|Good|4|
#        |TA	|Typical/Average|3|
#        |Fa	|Fair|2|
#        |Po	|Poor|1|
#        |0|Missing values|0|

# %%
combined.groupby(['Garage Qual']).count()
# Out:
#              index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Garage Qual
# 0              157   157   157          157        157           157
# Ex               3     3     3            3          3             3
# Fa             124   124   124          124        124           124
# Gd              24    24    24           24         24            24
# Po               5     5     5            5          5             5
# TA            2591  2591  2591         2591       2591          2591
#
#              Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Garage Qual                                      ...
# 0                 157     157    157        157  ...        157      157
# Ex                  3       3      3          3  ...          3        3
# Fa                124     124    124        124  ...        124      124
# Gd                 24      24     24         24  ...         24       24
# ...

# %%
combined['Garage Qual'] = combined['Garage Qual'].map({
    'Ex':4,
    'Gd':3,
    'TA':2,
    'Fa':1,
    'Po':0,
    0:0
    
})

# %%
combined['Garage Qual'].isnull().sum()
# Out:
# 0

# %%
combined['Garage Qual'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Garage Qual, dtype: int64

# %% [markdown]
# #### Garage Condition
# |Garage Cond (Ordinal): |Garage condition|Scale in dataframe|
# |-|-|-|
#        |Ex	|Excellent|5|
#        |Gd	|Good|4|
#        |TA	|Typical/Average|3|
#        |Fa	|Fair|2|
#        |Po	|Poor|1|
#        |0|Missing values|0|

# %%
combined.groupby(['Garage Cond']).count()
# Out:
#              index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Garage Cond
# 0              157   157   157          157        157           157
# Ex               3     3     3            3          3             3
# Fa              74    74    74           74         74            74
# Gd              15    15    15           15         15            15
# Po              14    14    14           14         14            14
# TA            2641  2641  2641         2641       2641          2641
#
#              Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Garage Cond                                      ...
# 0                 157     157    157        157  ...        157      157
# Ex                  3       3      3          3  ...          3        3
# Fa                 74      74     74         74  ...         74       74
# Gd                 15      15     15         15  ...         15       15
# ...

# %%
combined['Garage Cond'] = combined['Garage Cond'].map({
    'Ex':4,
    'Gd':3,
    'TA':2,
    'Fa':1,
    'Po':0,
    0:0
    
})

# %%
combined['Garage Cond'].isnull().sum()
# Out:
# 0

# %%
combined['Garage Cond'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Garage Cond, dtype: int64

# %% [markdown]
# #### Paved Drive
# |Paved Drive (Ordinal): |Paved driveway|Scale in dataframe|
# |-|-|-|
#     | Y	|Paved |2|
#      |  P	|Partial Pavement|1|
#       | N	|Dirt/Gravel|0|

# %%
combined.groupby(['Paved Drive']).count()
# Out:
#              index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  \
# Paved Drive
# N              215   215   215          215        215           215
# P               62    62    62           62         62            62
# Y             2627  2627  2627         2627       2627          2627
#
#              Lot Area  Street  Alley  Lot Shape  ...  Pool Area  Pool QC  \
# Paved Drive                                      ...
# N                 215     215    215        215  ...        215      215
# P                  62      62     62         62  ...         62       62
# Y                2627    2627   2627       2627  ...       2627     2627
#
#              Fence  Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  \
# Paved Drive
# N              215           215       215      215      215        215
# P               62            62        62       62       62         62
# Y             2627          2627      2627     2627     2627       2627
#
# ...

# %%
combined['Paved Drive'] = combined['Paved Drive'].map({
    'Y':2,
    'P':1,
    'N':0
    
})

# %%
combined['Paved Drive'].isnull().sum()
# Out:
# 0

# %%
combined['Paved Drive'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    0
# Name: Paved Drive, dtype: int64

# %% [markdown]
# #### Pool QC
# |Pool QC (Ordinal):| Pool quality|Scale in Dataframe|
# |-|-|-|
# |Ex	|Excellent|4|
#       | Gd	|Good|3|
#        |TA	|Average/Typical|2|
#        |Fa	|Fair|1|
#        |NA	|No Pool|0|
#        |0|Missing values|0|

# %%
combined.groupby(['Pool QC']).count()
# Out:
#          index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Pool QC
# 0         2891  2891  2891         2891       2891          2891      2891
# Ex           4     4     4            4          4             4         4
# Fa           2     2     2            2          2             2         2
# Gd           4     4     4            4          4             4         4
# TA           3     3     3            3          3             3         3
#
#          Street  Alley  Lot Shape  ...  Screen Porch  Pool Area  Fence  \
# Pool QC                            ...
# 0          2891   2891       2891  ...          2891       2891   2891
# Ex            4      4          4  ...             4          4      4
# Fa            2      2          2  ...             2          2      2
# Gd            4      4          4  ...             4          4      4
# TA            3      3          3  ...             3          3      3
#
# ...

# %%
combined['Pool QC'] = combined['Pool QC'].map({
    'Ex':4,
    'Gd':3,
    'TA':2,
    'Fa':1,
    'NA':0,
    0:0
    
})

# %%
combined['Pool QC'].isnull().sum()
# Out:
# 0

# %%
combined['Pool QC'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Pool QC, dtype: int64

# %% [markdown]
# #### Fence
# |Fence (Ordinal): |Fence quality|Scale in dataframe|
# |-|-|-|
#        |GdPrv	|Good Privacy|4|
#        |MnPrv	|Minimum Privacy|3|
#        |GdWo	|Good Wood|2|
#        |MnWw	|Minimum Wood/Wire|1|
#        |NA	|No Fence|0|

# %%
combined.groupby(['Fence']).count()
# Out:
#        index    Id   PID  MS SubClass  MS Zoning  Lot Frontage  Lot Area  \
# Fence
# 0       2334  2334  2334         2334       2334          2334      2334
# GdPrv    118   118   118          118        118           118       118
# GdWo     112   112   112          112        112           112       112
# MnPrv    328   328   328          328        328           328       328
# MnWw      12    12    12           12         12            12        12
#
#        Street  Alley  Lot Shape  ...  Screen Porch  Pool Area  Pool QC  \
# Fence                            ...
# 0        2334   2334       2334  ...          2334       2334     2334
# GdPrv     118    118        118  ...           118        118      118
# GdWo      112    112        112  ...           112        112      112
# MnPrv     328    328        328  ...           328        328      328
# MnWw       12     12         12  ...            12         12       12
#
# ...

# %%
combined['Fence'] = combined['Fence'].map({
    'GdPrv':4,
    'MnPrv':3,
    'GdWo':2,
    'MnWw':1,
    'NA':0,
    0:0
    
})

# %%
combined['Fence'].isnull().sum()
# Out:
# 0

# %%
combined['Fence'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Fence, dtype: int64

# %%
train_data = combined[combined['split'] == 'Train']

# %%
test_data = combined[combined['split']=='Test']

# %%
train_data.to_csv('./datasets/cleaned_train.csv')

# %%
test_data.to_csv('./datasets/cleaned_test.csv')

# %%
train_data.drop(columns='split')
# Out:
#       index    Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area  \
# 0         0   109  533352170           60        RL   7420.122878     13517
# 1         1   544  531379050           60        RL     43.000000     11492
# 2         2   153  535304180           20        RL     68.000000      7922
# 3         3   318  916386060           60        RL     73.000000      9802
# 4         4   255  906425045           50        RL     82.000000     14235
# ...     ...   ...        ...          ...       ...           ...       ...
# 2021   2046  1587  921126030           20        RL     79.000000     11449
# 2022   2047   785  905377130           30        RL   6775.040065     12342
# 2023   2048   916  909253010           50        RL     57.000000      7558
# 2024   2049   639  535179160           20        RL     80.000000     10400
# 2025   2050    10  527162130           60        RL     60.000000      7500
#
# ...
